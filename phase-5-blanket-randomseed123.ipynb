# %% [markdown]
# # PHASE 5 — Blanket Augmentation (Ablation Control, No Evidence-Filtering)

# %% [markdown]
# ## Cell 1 — Install dependencies

# %%
import subprocess, sys
def _pip_install(pkg):
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", pkg], check=False)
for pkg in ["ultralytics", "opencv-python-headless", "openpyxl"]:
    _pip_install(pkg)
import torch
print("Torch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
DEVICE = 0 if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 2.0 MB/s eta 0:00:00
# Torch: 2.10.0+cu128 | CUDA available: True
# Using device: 0

# %% [markdown]
# ## Cell 2 — Imports

# %%
import os, glob, json, random, shutil, time
import numpy as np
import pandas as pd
import cv2
import yaml as pyyaml
from ultralytics import YOLO

print("Imports OK")
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.
# Imports OK

# %% [markdown]
# ## Cell 3 — Configuration
#
# Blanket = ALL three Phase 3 degradation types applied with EQUAL, unfiltered
# probability -- no XAI evidence gate. Everything else (architecture, epochs,
# optimizer, baseline augmentation) is identical to Phase 5 Variant 1 for a fair
# comparison.

# %%
SEED = 123
IMG_SIZE = 640
EVAL_CONF = 0.001
IOU_THRESHOLD = 0.70

TRAIN_EPOCHS = 150
TRAIN_PATIENCE = 30
TRAIN_BATCH = 12
TRAIN_OPTIMIZER = "SGD"
TRAIN_LR0 = 0.01
TRAIN_LRF = 0.01
TRAIN_MOMENTUM = 0.937
TRAIN_WEIGHT_DECAY = 0.0005
TRAIN_WARMUP_EPOCHS = 3.0
TRAIN_WARMUP_MOMENTUM = 0.8
TRAIN_WARMUP_BIAS_LR = 0.1
TRAIN_SEED = SEED  # was hardcoded 42, now linked so changing SEED actually changes the Ultralytics-internal training seed
TRAIN_DETERMINISTIC = True
TRAIN_CLOSE_MOSAIC = 20
TRAIN_COS_LR = False

BASELINE_AUG = dict(
    hsv_h=0.02, hsv_s=0.7, hsv_v=0.5,
    degrees=10.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0,
    flipud=0.0, fliplr=0.5, bgr=0.0,
    mosaic=1.0, mixup=0.0, cutmix=0.0, copy_paste=0.0, copy_paste_mode="flip",
    auto_augment="randaugment", erasing=0.4,
)

# ---------------------------------------------------------------------------
# BLANKET augmentation -- all three Phase 3 degradation types, same probability
# and range as Variant 1's Low-Light/Noise (for fair comparison), PLUS Motion
# Blur added (which Variant 1 deliberately excluded due to lack of evidence).
# ---------------------------------------------------------------------------
BLANKET_LOWLIGHT_PROB = 0.35
BLANKET_LOWLIGHT_FACTOR_RANGE = (0.15, 0.85)
BLANKET_NOISE_PROB = 0.35
BLANKET_NOISE_STD_RANGE = (0.02, 0.16)
BLANKET_BLUR_PROB = 0.35
BLANKET_BLUR_KERNEL_RANGE = (5, 17)   # matches Phase 3's motion-blur severity kernels

random.seed(SEED)
np.random.seed(SEED)

OUTPUT_ROOT = f"/kaggle/working/phase5_blanket_seed{SEED}"
TRAINING_DIR = os.path.join(OUTPUT_ROOT, "training")
MODELS_DIR = os.path.join(OUTPUT_ROOT, "models")
RESULTS_DIR = os.path.join(OUTPUT_ROOT, "results")
LOGS_DIR = os.path.join(OUTPUT_ROOT, "logs")
PLOTS_DIR = os.path.join(OUTPUT_ROOT, "plots")
for d in [OUTPUT_ROOT, TRAINING_DIR, MODELS_DIR, RESULTS_DIR, LOGS_DIR, PLOTS_DIR]:
    os.makedirs(d, exist_ok=True)

print("Blanket augmentation configuration loaded.")
print("Low-light:", BLANKET_LOWLIGHT_PROB, BLANKET_LOWLIGHT_FACTOR_RANGE)
print("Noise    :", BLANKET_NOISE_PROB, BLANKET_NOISE_STD_RANGE)
print("Blur     :", BLANKET_BLUR_PROB, BLANKET_BLUR_KERNEL_RANGE)

DPI = 300
BEFORE_LABEL = "Baseline"
BLANKET_LABEL = "Blanket Augmentation"
# Out:
# Blanket augmentation configuration loaded.
# Low-light: 0.35 (0.15, 0.85)
# Noise    : 0.35 (0.02, 0.16)
# Blur     : 0.35 (5, 17)

# %% [markdown]
# ## Cell 4 — Locate Phase 3 output (before-model, clean+degraded test sets)

# %%
def find_phase3_root():
    candidates = []
    for root in ("/kaggle/input", "/kaggle/working"):
        for config_path in glob.glob(os.path.join(root, "**", "phase3_config.json"), recursive=True):
            d = os.path.dirname(config_path)
            if os.path.isdir(os.path.join(d, "degraded_datasets")):
                candidates.append(d)
    return sorted(set(candidates))

phase3_candidates = find_phase3_root()
if not phase3_candidates:
    raise FileNotFoundError("No Phase 3 output found. Add the Phase 3 output zip as a Kaggle Input dataset.")
PHASE3_ROOT = phase3_candidates[0]
print("PHASE3_ROOT:", PHASE3_ROOT)

with open(os.path.join(PHASE3_ROOT, "phase3_config.json")) as f:
    phase3_config = json.load(f)

BEFORE_MODEL_PATH = os.path.join(PHASE3_ROOT, "model", "best.pt")
if not os.path.exists(BEFORE_MODEL_PATH):
    cands = glob.glob("/kaggle/input/**/best.pt", recursive=True)
    if not cands:
        raise FileNotFoundError("No baseline best.pt found.")
    BEFORE_MODEL_PATH = cands[0]
print("BEFORE_MODEL_PATH:", BEFORE_MODEL_PATH)

CLEAN_TEST_IMAGES_DIR = os.path.join(PHASE3_ROOT, "clean_test_set", "images")
DEGRADED_DIR = os.path.join(PHASE3_ROOT, "degraded_datasets")
DEGRADATION_DIRS = {
    "Gaussian Noise": os.path.join(DEGRADED_DIR, "gaussian_noise"),
    "Motion Blur": os.path.join(DEGRADED_DIR, "motion_blur"),
    "Low Light": os.path.join(DEGRADED_DIR, "low_light"),
}
for name, d in DEGRADATION_DIRS.items():
    print(f"{name} exists: {os.path.isdir(d)} -> {d}")

SEVERITY_PARAMS = phase3_config.get("severity_params", {})
SEVERITIES = sorted({int(s) for grp in SEVERITY_PARAMS.values() for s in grp.keys()}) or [1, 2, 3, 4]
CLASS_NAMES = phase3_config.get("class_names", ["Fire", "Smoke"])
NUM_CLASSES = len(CLASS_NAMES)
print("Severities:", SEVERITIES, "| Classes:", CLASS_NAMES)
# Out:
# PHASE3_ROOT: /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3
# BEFORE_MODEL_PATH: /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/model/best.pt
# Gaussian Noise exists: True -> /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise
# Motion Blur exists: True -> /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur
# Low Light exists: True -> /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light
# Severities: [1, 2, 3, 4] | Classes: ['Fire', 'Smoke']

# %% [markdown]
# ## Cell 5 — Locate / download the training dataset (train+val)

# %%
train_data_candidates = glob.glob("/kaggle/input/**/train/images", recursive=True) + \
                         glob.glob("/kaggle/working/**/train/images", recursive=True)

if train_data_candidates:
    TRAIN_DATASET_ROOT = os.path.dirname(os.path.dirname(train_data_candidates[0]))
    print("Using existing dataset at:", TRAIN_DATASET_ROOT)
else:
    print("Downloading from Roboflow...")
    _pip_install("roboflow")
    from roboflow import Roboflow
    ROBOFLOW_API_KEY = "qNZt21Yr4LTdIaH6fUXC"
    rf = Roboflow(api_key=ROBOFLOW_API_KEY)
    project = rf.workspace("md-s-workspace").project("fire_smoke_detection-tmqte")
    dataset = project.version(4).download("yolov11")
    TRAIN_DATASET_ROOT = dataset.location
    print("Downloaded to:", TRAIN_DATASET_ROOT)

DATA_YAML_PATH = os.path.join(TRAIN_DATASET_ROOT, "data.yaml")
print("data.yaml:", DATA_YAML_PATH, "| exists:", os.path.exists(DATA_YAML_PATH))
# Out:
# Using existing dataset at: /kaggle/working/fire_smoke_detection-4
# data.yaml: /kaggle/working/fire_smoke_detection-4/data.yaml | exists: True

# %% [markdown]
# ## Cell 6 — Patch build_transforms with BLANKET (unfiltered) augmentation
#
# Idempotent patch (safe to re-run), identical mechanism to Variant 1's patch --
# only the transform class differs (adds Motion Blur, no evidence-gate applied).

# %%
from ultralytics.data.dataset import YOLODataset

class BlanketDegradationAugment:
    """Blanket (non-evidence-based) augmentation: applies ALL THREE Phase 3
    degradation types with equal, unfiltered probability -- used only as an
    ablation control against the evidence-constrained targeted (Variant 1) run."""
    def __init__(self, p_lowlight, lowlight_range, p_noise, noise_std_range,
                 p_blur, blur_kernel_range):
        self.p_lowlight = p_lowlight
        self.lowlight_range = lowlight_range
        self.p_noise = p_noise
        self.noise_std_range = noise_std_range
        self.p_blur = p_blur
        self.blur_kernel_range = blur_kernel_range

    def _apply_lowlight(self, img):
        factor = random.uniform(*self.lowlight_range)
        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV).astype(np.float32)
        hsv[:, :, 2] = np.clip(hsv[:, :, 2] * factor, 0, 255)
        return cv2.cvtColor(hsv.astype(np.uint8), cv2.COLOR_HSV2BGR)

    def _apply_noise(self, img):
        std = random.uniform(*self.noise_std_range)
        img_f = img.astype(np.float32) / 255.0
        noise = np.random.normal(0.0, std, img_f.shape).astype(np.float32)
        return (np.clip(img_f + noise, 0, 1) * 255.0).astype(np.uint8)

    def _apply_blur(self, img):
        k = random.choice(range(self.blur_kernel_range[0], self.blur_kernel_range[1] + 1, 2))
        kernel = np.zeros((k, k), dtype=np.float32)
        kernel[k // 2, :] = 1.0 / k
        return cv2.filter2D(img, -1, kernel)

    def __call__(self, labels):
        img = labels["img"]
        if random.random() < self.p_lowlight:
            img = self._apply_lowlight(img)
        if random.random() < self.p_noise:
            img = self._apply_noise(img)
        if random.random() < self.p_blur:
            img = self._apply_blur(img)
        labels["img"] = img
        return labels


if not hasattr(YOLODataset, "_phase5_true_original_build_transforms"):
    current = YOLODataset.__dict__.get("build_transforms")
    while current is not None and getattr(current, "_is_phase5_patch", False):
        current = current._wrapped_original
    YOLODataset._phase5_true_original_build_transforms = current
    print("Captured the TRUE original build_transforms.")
else:
    print("TRUE original build_transforms already captured -- reusing it.")

_true_original = YOLODataset._phase5_true_original_build_transforms

def _patched_build_transforms(self, hyp=None):
    transforms = _true_original(self, hyp)
    if getattr(self, "augment", False):
        blanket = BlanketDegradationAugment(
            p_lowlight=BLANKET_LOWLIGHT_PROB, lowlight_range=BLANKET_LOWLIGHT_FACTOR_RANGE,
            p_noise=BLANKET_NOISE_PROB, noise_std_range=BLANKET_NOISE_STD_RANGE,
            p_blur=BLANKET_BLUR_PROB, blur_kernel_range=BLANKET_BLUR_KERNEL_RANGE,
        )
        insert_at = len(transforms.transforms) - 1 if len(transforms.transforms) > 0 else 0
        transforms.transforms.insert(insert_at, blanket)
        print(f"[Blanket] Inserted BlanketDegradationAugment at position {insert_at} "
              f"(pipeline now has {len(transforms.transforms)} transforms).")
    return transforms

_patched_build_transforms._is_phase5_patch = True
_patched_build_transforms._wrapped_original = _true_original
YOLODataset.build_transforms = _patched_build_transforms
print("Patched YOLODataset.build_transforms (blanket, idempotent).")
# Out:
# Captured the TRUE original build_transforms.
# Patched YOLODataset.build_transforms (blanket, idempotent).

# %% [markdown]
# ## Cell 7 — Evaluation utility (per-class AP50 included)

# %%
def make_data_yaml(images_dir, yaml_path, names):
    split_root = os.path.dirname(images_dir)
    data = {"path": split_root, "train": "images", "val": "images",
            "names": {i: n for i, n in enumerate(names)}}
    with open(yaml_path, "w") as f:
        pyyaml.dump(data, f)
    return yaml_path

def evaluate_model(model, images_dir, name, conf=EVAL_CONF, iou=IOU_THRESHOLD, imgsz=IMG_SIZE):
    yaml_path = os.path.join(LOGS_DIR, f"data_{name}.yaml")
    make_data_yaml(images_dir, yaml_path, CLASS_NAMES)
    metrics = model.val(data=yaml_path, imgsz=imgsz, conf=conf, iou=iou, split="val",
                         device=DEVICE, verbose=False, plots=False, save_json=False)
    per_class_ap50 = {}
    try:
        ap50_per_class = metrics.box.ap50
        for i, cname in enumerate(CLASS_NAMES):
            per_class_ap50[f"{cname}_AP50"] = float(ap50_per_class[i]) if i < len(ap50_per_class) else None
    except Exception:
        for cname in CLASS_NAMES:
            per_class_ap50[f"{cname}_AP50"] = None
    return {
        "Precision": float(metrics.box.mp),
        "Recall": float(metrics.box.mr),
        "mAP50": float(metrics.box.map50),
        "mAP50_95": float(metrics.box.map),
        **per_class_ap50,
    }

def evaluate_all_conditions(model, tag):
    rows = []
    m = evaluate_model(model, CLEAN_TEST_IMAGES_DIR, f"{tag}_clean")
    rows.append({"Model": tag, "Degradation": "Clean", "Severity": 0, **m})
    for deg_name, deg_dir in DEGRADATION_DIRS.items():
        deg_key = deg_name.lower().replace(" ", "_")
        for sev in SEVERITIES:
            sev_dir = os.path.join(deg_dir, f"severity_{sev}", "images")
            if not os.path.isdir(sev_dir):
                continue
            m = evaluate_model(model, sev_dir, f"{tag}_{deg_key}_sev{sev}")
            rows.append({"Model": tag, "Degradation": deg_name, "Severity": sev, **m})
    return pd.DataFrame(rows)

print("Evaluation utility ready.")
# Out:
# Evaluation utility ready.

# %% [markdown]
# ## Cell 8 — BEFORE evaluation (baseline model, for reference)

# %%
before_model = YOLO(BEFORE_MODEL_PATH)
before_df = evaluate_all_conditions(before_model, "Before")
before_csv = os.path.join(RESULTS_DIR, "before_results.csv")
before_df.to_csv(before_csv, index=False)
print("Saved:", before_csv)
before_df
# Out:
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO11s summary (fused): 101 layers, 9,413,574 parameters, 0 gradients, 21.4 GFLOPs
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 9.4MB/s 0.1s
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 9.5±3.1 MB/s, size: 41.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 278.0it/s 6.2s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.5it/s 19.6s0.2s
#                    all       1715       2790      0.869      0.763      0.828      0.625
# Speed: 0.7ms preprocess, 8.1ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 28.5±3.8 MB/s, size: 190.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_1/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 265.3it/s 6.5s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_1 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.8it/s 18.5s0.2s
#                    all       1715       2790      0.856      0.716      0.784      0.591
# Speed: 0.7ms preprocess, 8.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 32.8±15.9 MB/s, size: 234.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_2/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 236.3it/s 7.3s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_2 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.7it/s 19.0s0.2s
#                    all       1715       2790      0.776      0.577      0.636      0.485
# Speed: 0.7ms preprocess, 8.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 23.5±14.0 MB/s, size: 283.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_3/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 229.7it/s 7.5s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_3 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.4it/s 20.1s0.2s
#                    all       1715       2790      0.783      0.465      0.516      0.402
# Speed: 0.7ms preprocess, 9.0ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 48.9±22.9 MB/s, size: 362.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 216.2it/s 7.9s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.3it/s 20.5s0.2s
#                    all       1715       2790      0.664      0.356      0.371      0.276
# Speed: 0.7ms preprocess, 9.2ms inference, 0.0ms loss, 0.7ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 10.8±2.7 MB/s, size: 91.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_1/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 290.5it/s 5.9s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_1 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 21.0s0.2s
#                    all       1715       2790      0.877      0.757      0.827      0.624
# Speed: 0.7ms preprocess, 9.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 12.2±3.5 MB/s, size: 60.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_2/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 292.9it/s 5.9s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_2 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.7s0.2s
#                    all       1715       2790      0.872      0.732       0.81      0.603
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 12.4±4.7 MB/s, size: 67.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_3/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 289.3it/s 5.9s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_3 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.3it/s 20.4s0.2s
#                    all       1715       2790      0.871       0.69      0.775      0.566
# Speed: 0.7ms preprocess, 9.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 10.7±3.0 MB/s, size: 55.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 301.8it/s 5.7s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.9s0.2s
#                    all       1715       2790      0.818      0.657      0.725      0.514
# Speed: 0.7ms preprocess, 9.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 14.2±2.9 MB/s, size: 72.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_1/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 285.3it/s 6.0s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_1 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.3it/s 20.5s0.2s
#                    all       1715       2790      0.876      0.759      0.827      0.627
# Speed: 0.7ms preprocess, 9.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 12.0±4.2 MB/s, size: 60.8 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_2/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 284.1it/s 6.0s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_2 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.3it/s 20.5s0.2s
#                    all       1715       2790      0.874      0.762      0.827      0.627
# Speed: 0.7ms preprocess, 9.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 10.2±3.2 MB/s, size: 49.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_3/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 293.8it/s 5.8s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_3 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.8s0.2s
#                    all       1715       2790      0.877      0.751      0.821      0.624
# Speed: 0.7ms preprocess, 9.6ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 10.7±0.9 MB/s, size: 50.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 297.3it/s 5.8s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.3it/s 20.6s0.2s
#                    all       1715       2790      0.878      0.726      0.791      0.599
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Saved: /kaggle/working/phase5_blanket_seed123/results/before_results.csv
#      Model     Degradation  Severity  Precision    Recall     mAP50  mAP50_95  \
# 0   Before           Clean         0   0.869361  0.762934  0.828040  0.625484
# 1   Before  Gaussian Noise         1   0.855555  0.716088  0.783998  0.590691
# 2   Before  Gaussian Noise         2   0.775929  0.576955  0.636428  0.484954
# 3   Before  Gaussian Noise         3   0.783000  0.465214  0.516404  0.402309
# 4   Before  Gaussian Noise         4   0.664069  0.356103  0.370867  0.276117
# 5   Before     Motion Blur         1   0.877249  0.756887  0.827109  0.624187
# 6   Before     Motion Blur         2   0.871974  0.731861  0.809976  0.603373
# 7   Before     Motion Blur         3   0.870828  0.690419  0.775272  0.566320
# 8   Before     Motion Blur         4   0.817626  0.657045  0.724563  0.514225
# 9   Before       Low Light         1   0.875656  0.758979  0.826797  0.627010
# 10  Before       Low Light         2   0.874133  0.762090  0.827069  0.627198
# 11  Before       Low Light         3   0.876896  0.751325  0.820986  0.624414
# 12  Before       Low Light         4   0.877971  0.725938  0.791391  0.599147
#
#     Fire_AP50  Smoke_AP50
# 0    0.872152    0.783928
# 1    0.851942    0.716054
# 2    0.761404    0.511453
# 3    0.644998    0.387811
# 4    0.513996    0.227737
# 5    0.873843    0.780376
# 6    0.851552    0.768400
# 7    0.818269    0.732274
# 8    0.757586    0.691539
# 9    0.870845    0.782749
# 10   0.870212    0.783926
# 11   0.867319    0.774653
# 12   0.843162    0.739619

# %% [markdown]
# ## Cell 9 — Fresh YOLO11s training with BLANKET augmentation

# %%
blanket_model = YOLO("yolo11s.pt")

run_name = f"yolo11s_phase5_blanket_seed{SEED}"

train_results = blanket_model.train(
    data=DATA_YAML_PATH,
    epochs=TRAIN_EPOCHS,
    patience=TRAIN_PATIENCE,
    batch=TRAIN_BATCH,
    imgsz=IMG_SIZE,
    device=DEVICE,
    project=TRAINING_DIR,
    name=run_name,
    exist_ok=True,
    optimizer=TRAIN_OPTIMIZER,
    lr0=TRAIN_LR0,
    lrf=TRAIN_LRF,
    momentum=TRAIN_MOMENTUM,
    weight_decay=TRAIN_WEIGHT_DECAY,
    warmup_epochs=TRAIN_WARMUP_EPOCHS,
    warmup_momentum=TRAIN_WARMUP_MOMENTUM,
    warmup_bias_lr=TRAIN_WARMUP_BIAS_LR,
    seed=TRAIN_SEED,
    deterministic=TRAIN_DETERMINISTIC,
    close_mosaic=TRAIN_CLOSE_MOSAIC,
    cos_lr=TRAIN_COS_LR,
    verbose=True,
    plots=False,
    **BASELINE_AUG,
)

BLANKET_MODEL_PATH = os.path.join(TRAINING_DIR, run_name, "weights", "best.pt")
print("\nTraining complete.")
print("BLANKET_MODEL_PATH:", BLANKET_MODEL_PATH, "| exists:", os.path.exists(BLANKET_MODEL_PATH))

bundled_blanket_path = os.path.join(MODELS_DIR, "blanket_best.pt")
shutil.copy2(BLANKET_MODEL_PATH, bundled_blanket_path)
print("Copied best.pt to:", bundled_blanket_path)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 199.4MB/s 0.1s
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=12, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=20, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/fire_smoke_detection-4/data.yaml, degrees=10.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.02, hsv_s=0.7, hsv_v=0.5, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11s_phase5_blanket_seed123, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=30, perspective=0.0, plots=False, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/phase5_blanket_seed123/training, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/phase5_blanket_seed123/training/yolo11s_phase5_blanket_seed123, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=123, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820182  ultralytics.nn.modules.head.Detect           [2, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,428,566 parameters, 9,428,550 gradients, 21.7 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'weights/yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 192.5MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1244.8±408.3 MB/s, size: 43.0 KB)
# train: Scanning /kaggle/working/fire_smoke_detection-4/train/labels... 8089 images, 1419 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 8089/8089 1.4Kit/s 5.6s0.1s
# train: /kaggle/working/fire_smoke_detection-4/train/images/middle_-2348-_jpg.rf.a4cd078442e8fac068e55eb1c2557728.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: New cache created: /kaggle/working/fire_smoke_detection-4/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# [Blanket] Inserted BlanketDegradationAugment at position 7 (pipeline now has 9 transforms).
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 324.6±173.4 MB/s, size: 35.3 KB)
# val: Scanning /kaggle/working/fire_smoke_detection-4/valid/labels... 1706 images, 275 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1706/1706 1.5Kit/s 1.1s0.0s
# val: New cache created: /kaggle/working/fire_smoke_detection-4/valid/labels.cache
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.00046875), 87 bias(decay=0.0)
# Using 8088 train, 1706 val images for fraction=1.0 at imgsz=640
# Using 2 dataloader workers
# Logging results to /kaggle/working/phase5_blanket_seed123/training/yolo11s_phase5_blanket_seed123
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      2.97G      1.521      2.144      1.633         41        640: 100% ━━━━━━━━━━━━ 674/674 4.2it/s 2:420.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 2.7it/s 26.7s0.2ss
#                    all       1706       2867       0.71      0.443      0.491      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      3.77G      1.878      2.047      1.839         33        640: 0% ──────────── 0/674  0.2s
# `get_trial_id` is meant to only be called inside a function that is executed by a Tuner or Trainer. Returning `None`.
#       2/150      3.77G      1.418      1.616      1.555         36        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.697      0.492      0.553      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/150      3.78G      1.553      1.789      1.648         18        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.643      0.378      0.395      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/150      3.78G      1.622      1.888       1.71         39        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:320.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.718      0.442      0.506      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/150      3.78G      1.559      1.757      1.665         38        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.702      0.499      0.562      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/150      3.78G      1.499      1.661      1.622         30        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:290.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.785      0.477      0.555      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/150      3.78G      1.453      1.572      1.594         45        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.762      0.558      0.625      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/150      3.78G      1.409      1.484      1.553         49        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.803      0.551      0.631      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/150      3.78G      1.396      1.474      1.545         63        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.778      0.592      0.648      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/150      3.78G      1.362      1.421      1.527         34        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.748      0.603      0.661      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/150      3.78G      1.361      1.408      1.514         31        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.793      0.617      0.681      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/150      3.78G      1.347      1.363      1.497         37        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.1s0.2s
#                    all       1706       2867      0.779      0.609      0.668      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/150      3.78G      1.326      1.344       1.49         39        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.802      0.618      0.692      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/150      3.78G       1.31      1.309      1.472         28        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.793      0.635      0.694      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/150      3.78G      1.291      1.295      1.465         32        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.812      0.626      0.696      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/150      3.78G       1.28      1.262       1.46         28        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.806       0.62      0.694       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/150      3.78G      1.268      1.236      1.442         28        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.3s0.2s
#                    all       1706       2867      0.801       0.64      0.698      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/150      3.78G      1.276      1.251      1.451         27        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.825      0.636      0.711      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/150      3.78G      1.247      1.218      1.434         48        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867       0.82      0.657      0.717      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/150      3.78G      1.241      1.209      1.432         32        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.817      0.642       0.72      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/150      3.78G      1.237      1.184      1.428         46        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.845      0.639      0.725      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/150      3.78G      1.231       1.17      1.419         34        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.813      0.667      0.724      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/150      3.78G      1.221      1.172      1.412         49        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.843      0.653      0.725      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/150      3.78G      1.207      1.162      1.412         33        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.846      0.663      0.737      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/150      3.78G      1.188      1.116      1.383         28        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.845      0.675      0.743      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/150      3.78G      1.204      1.133        1.4         37        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.839      0.668      0.745        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/150      3.78G      1.186      1.106      1.378         33        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.821      0.671      0.735      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/150      3.78G      1.194      1.134      1.389         30        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.824       0.66      0.737      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/150      3.78G      1.183      1.131       1.39         24        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.842      0.673      0.743      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/150      3.78G      1.173      1.094      1.374         38        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.827      0.664      0.743      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/150      3.78G      1.153      1.085      1.362         42        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:320.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.834      0.663       0.74      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/150      3.78G      1.157      1.075      1.363         34        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.834      0.678      0.748      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/150      3.78G      1.159      1.088      1.366         35        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.834      0.673      0.753      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/150      3.78G      1.166      1.073      1.372         27        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.1s0.2s
#                    all       1706       2867      0.831      0.682      0.756      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/150      3.78G      1.151      1.057      1.348         14        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.869      0.676      0.759      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/150      3.78G      1.155      1.058      1.357         23        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.851      0.675      0.759      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/150      3.78G      1.144       1.04      1.351         27        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.1s0.2s
#                    all       1706       2867      0.845      0.679       0.76      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/150      3.78G      1.135      1.038      1.346         18        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:320.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.857      0.674       0.76      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/150      3.78G      1.132      1.033      1.344         35        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.825      0.683      0.763       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/150      3.78G      1.141       1.04       1.35         31        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.863      0.682       0.77      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/150      3.78G       1.13      1.016      1.349         30        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.843      0.675       0.76       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/150      3.78G      1.127      1.016       1.34         35        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:320.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.859      0.686      0.765       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/150      3.78G      1.119      1.006      1.341         57        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.859      0.694      0.774      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/150      3.78G      1.111     0.9892      1.326         28        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.853      0.693      0.774      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/150      3.78G      1.125      1.016      1.341         28        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.843      0.701      0.775       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/150      3.78G      1.109      0.989      1.329         50        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.1s0.2s
#                    all       1706       2867      0.856      0.694      0.772      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/150      3.78G      1.113          1      1.335         36        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.863      0.693      0.776      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/150      3.78G      1.117     0.9977      1.334         30        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.855      0.701      0.778      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/150      3.78G      1.098     0.9703      1.316         44        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.2it/s 11.7s0.2s
#                    all       1706       2867      0.852      0.701      0.775      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/150      3.78G      1.086     0.9617      1.309         21        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.847      0.708      0.782      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/150      3.78G      1.098     0.9837       1.32         50        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.861      0.715      0.786      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/150      3.78G      1.089     0.9633      1.314         40        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.2it/s 11.7s0.2s
#                    all       1706       2867       0.85      0.711      0.782      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/150      3.78G      1.091     0.9654      1.311         36        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.842      0.714      0.782      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/150      3.78G      1.076     0.9557      1.302         45        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.2it/s 11.6s0.2s
#                    all       1706       2867       0.86      0.706      0.783      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/150      3.78G      1.083     0.9444      1.305         55        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.856      0.713      0.788      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/150      3.78G      1.079     0.9413      1.302         33        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.853      0.717       0.79       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/150      3.78G      1.076     0.9442      1.306         42        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.3s0.2s
#                    all       1706       2867       0.84      0.724      0.788      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/150      3.78G      1.073     0.9358      1.304         31        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.3s0.2s
#                    all       1706       2867      0.847      0.731      0.795       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/150      3.78G      1.055     0.9201      1.295         32        640: 100% ━━━━━━━━━━━━ 674/674 4.2it/s 2:390.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.1s0.2s
#                    all       1706       2867       0.84      0.722      0.791      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/150      3.78G      1.061     0.9288      1.293         25        640: 100% ━━━━━━━━━━━━ 674/674 4.2it/s 2:390.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.1s0.2s
#                    all       1706       2867      0.849      0.718      0.792       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/150      3.78G      1.073     0.9336      1.296         39        640: 100% ━━━━━━━━━━━━ 674/674 4.2it/s 2:400.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.843      0.714      0.791      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/150      3.78G      1.048     0.9095      1.285         34        640: 100% ━━━━━━━━━━━━ 674/674 4.2it/s 2:400.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.1s0.2s
#                    all       1706       2867      0.855      0.718      0.798      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/150      3.78G      1.053     0.9085      1.288         37        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.844      0.728      0.799      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/150      3.78G      1.055     0.9136      1.292         66        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.844      0.728        0.8      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/150      3.78G      1.058     0.9125      1.287         31        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.849      0.739      0.804      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/150      3.78G      1.039     0.8903      1.275         29        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.858      0.729      0.801      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/150      3.78G      1.042     0.8976      1.278         16        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.855      0.724      0.801      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/150      3.78G       1.05     0.8903      1.283         35        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.869      0.729      0.803       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/150      3.78G      1.034     0.8882      1.273         31        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.862      0.731      0.805      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/150      3.78G      1.042     0.8891      1.277         46        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.861      0.732      0.805      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/150      3.78G      1.035     0.8758      1.269         34        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.861      0.732      0.804      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/150      3.78G      1.023     0.8617      1.263         32        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:380.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.864      0.735      0.804      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/150      3.78G      1.026       0.87      1.272         45        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.857      0.741      0.805      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/150      3.78G       1.03     0.8742      1.272         18        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:370.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.855       0.75      0.806      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/150      3.78G      1.023     0.8575      1.263         31        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.861      0.742      0.807      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/150      3.78G      1.013     0.8451      1.256         42        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:370.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.855      0.747      0.809      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/150      3.78G      1.024     0.8534      1.263         48        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.861      0.751      0.808      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/150      3.78G      1.015     0.8601      1.263         46        640: 100% ━━━━━━━━━━━━ 674/674 4.2it/s 2:390.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.7s0.2s
#                    all       1706       2867      0.856      0.747      0.808      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/150      3.78G      1.005     0.8308       1.25         25        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867       0.86      0.744      0.809      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/150      3.78G      1.018      0.846      1.258         41        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.862       0.75      0.811      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/150      3.78G          1     0.8301      1.249         29        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:370.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.866      0.747      0.812      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/150      3.78G      1.007     0.8331      1.247         30        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.856      0.749      0.814       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/150      3.78G      1.003      0.829      1.248         24        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.855      0.755      0.813      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/150      3.78G     0.9938     0.8248      1.247         25        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.2it/s 11.7s0.2s
#                    all       1706       2867      0.853      0.758      0.814      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/150      3.78G      1.001     0.8303      1.251         29        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.861      0.751      0.813      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/150      3.78G     0.9877     0.8115      1.238         23        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:370.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.2it/s 11.7s0.2s
#                    all       1706       2867      0.855      0.755      0.813      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/150      3.78G     0.9924     0.8083      1.239         48        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.866      0.747      0.813      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/150      3.78G      0.999     0.8052      1.243         32        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.863      0.751      0.814      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/150      3.78G      0.987     0.8131      1.237         27        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:380.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.855      0.754      0.815      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/150      3.78G     0.9898      0.822      1.241         49        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867       0.85      0.755      0.816      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/150      3.78G     0.9831      0.799      1.231         36        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:370.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.851      0.758      0.817      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/150      3.78G     0.9833     0.7909       1.23         59        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.843      0.764      0.817      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/150      3.78G     0.9714     0.7776       1.22         45        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.845      0.758      0.816      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/150      3.78G     0.9732     0.7896      1.228         27        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.854      0.749      0.817      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/150      3.78G     0.9729     0.7842       1.23         44        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.2it/s 11.7s0.2s
#                    all       1706       2867      0.868       0.74      0.818      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/150      3.78G     0.9639     0.7678      1.217         31        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:350.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.854      0.752      0.819      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     101/150      3.78G     0.9556     0.7651      1.223         27        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     117/150      3.78G      0.928     0.7269      1.198         51        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.861      0.764      0.823      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     118/150      3.78G     0.9276     0.7137      1.196         41        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:370.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.863      0.761      0.824      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     119/150      3.78G     0.9171      0.701      1.183         28        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:380.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.867      0.761      0.824      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     120/150      3.78G     0.9164      0.705      1.186         39        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.867      0.759      0.824      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     121/150      3.78G     0.9154      0.703      1.186         21        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.867      0.761      0.824      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     122/150      3.78G     0.9056     0.6942       1.18         28        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.1s0.2s
#                    all       1706       2867      0.866      0.763      0.824      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     123/150      3.78G     0.8928     0.6762      1.174         32        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.868      0.764      0.824      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     124/150      3.78G     0.9109     0.6869      1.179         48        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.868      0.765      0.825      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     125/150      3.78G     0.8946     0.6798      1.173         28        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.866      0.766      0.825      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     126/150      3.78G     0.8842     0.6722      1.172         28        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.867      0.765      0.824      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     127/150      3.78G      0.897     0.6823      1.179         50        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.864      0.768      0.824      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     128/150      3.78G     0.8937     0.6784      1.172         42        640: 100% ━━━━━━━━━━━━ 674/674 4.3it/s 2:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 5.9it/s 12.2s0.2s
#                    all       1706       2867      0.866      0.768      0.825      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     129/150      3.78G     0.8975     0.6666      1.177         48        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:320.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.865      0.766      0.825      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     130/150      3.78G     0.8905     0.6657      1.169         60        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:340.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.864      0.767      0.825      0.596
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# [Blanket] Inserted BlanketDegradationAugment at position 7 (pipeline now has 9 transforms).
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     131/150      3.78G      0.864     0.5795      1.161         15        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:330.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.864      0.766      0.825      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     132/150      3.78G     0.8512     0.5545      1.149         23        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:300.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.864      0.768      0.826      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     133/150      3.78G     0.8399      0.543      1.142         18        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:320.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.865      0.768      0.826      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     134/150      3.78G     0.8393     0.5429      1.142         18        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.864       0.77      0.827      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     135/150      3.78G     0.8316     0.5405      1.137         18        640: 100% ━━━━━━━━━━━━ 674/674 4.4it/s 2:320.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.865      0.767      0.827      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     136/150      3.78G     0.8243     0.5238      1.131         11        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:300.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.865      0.767      0.827      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     137/150      3.78G     0.8213     0.5214      1.128         20        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:300.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.864      0.768      0.827      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     138/150      3.78G     0.8134     0.5144      1.126         10        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:290.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.2it/s 11.7s0.2s
#                    all       1706       2867      0.866      0.767      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     139/150      3.78G      0.814     0.5078      1.123         19        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.867      0.766      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/150      3.78G     0.8083     0.5043      1.117         29        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:290.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.8s0.2s
#                    all       1706       2867      0.867      0.765      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/150      3.78G     0.8015     0.5028      1.119         17        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:300.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.7s0.2s
#                    all       1706       2867      0.866      0.764      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/150      3.78G     0.7946     0.4931      1.113         16        640: 100% ━━━━━━━━━━━━ 674/674 4.6it/s 2:270.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.867      0.763      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/150      3.78G      0.803     0.5013       1.12         23        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:290.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.868      0.762      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/150      3.78G      0.802     0.4936      1.115         41        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.2it/s 11.7s0.2s
#                    all       1706       2867      0.869      0.761      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/150      3.78G     0.7878      0.481      1.107         27        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:300.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867      0.869      0.762      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/150      3.78G     0.7859     0.4838      1.103         13        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.7s0.2s
#                    all       1706       2867       0.87      0.759      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/150      3.78G      0.782     0.4781      1.103         19        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:300.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 11.9s0.2s
#                    all       1706       2867      0.871       0.76      0.826      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/150      3.78G     0.7789     0.4749      1.102         18        640: 100% ━━━━━━━━━━━━ 674/674 4.6it/s 2:280.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.1it/s 11.9s0.2s
#                    all       1706       2867       0.87      0.761      0.827      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/150      3.78G     0.7812     0.4713      1.101         18        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.871       0.76      0.827      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/150      3.78G     0.7825     0.4737      1.101         13        640: 100% ━━━━━━━━━━━━ 674/674 4.5it/s 2:310.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 6.0it/s 12.0s0.2s
#                    all       1706       2867      0.871       0.76      0.826      0.598
#
# 150 epochs completed in 6.948 hours.
# Optimizer stripped from /kaggle/working/phase5_blanket_seed123/training/yolo11s_phase5_blanket_seed123/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/phase5_blanket_seed123/training/yolo11s_phase5_blanket_seed123/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/phase5_blanket_seed123/training/yolo11s_phase5_blanket_seed123/weights/best.pt...
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO11s summary (fused): 101 layers, 9,413,574 parameters, 0 gradients, 21.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 72/72 2.8it/s 25.5s0.2ss
#                    all       1706       2867      0.871       0.76      0.826      0.598
#                   Fire       1173       1946      0.876      0.792       0.85      0.608
#                  Smoke        680        921      0.867      0.729      0.803      0.589
# Speed: 0.2ms preprocess, 12.6ms inference, 0.0ms loss, 0.9ms postprocess per image
#
# Training complete.
# BLANKET_MODEL_PATH: /kaggle/working/phase5_blanket_seed123/training/yolo11s_phase5_blanket_seed123/weights/best.pt | exists: True
# Copied best.pt to: /kaggle/working/phase5_blanket_seed123/models/blanket_best.pt

# %% [markdown]
# ## Cell 9b — If disconnected mid-training, run this to resume, then re-run Cell 10 onward

# %%
for root, dirs, files in os.walk("/kaggle/input"):
    for f in files:
        if f.endswith(".pt"):
            print(os.path.join(root, f))
# Out:
# /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/model/best.pt
# /kaggle/input/datasets/sumiyahaider/best-pt/best (2).pt

# %%
BLANKET_MODEL_PATH = "/kaggle/input/datasets/sumiyahaider/best-pt/best (2).pt"
print("Using:", BLANKET_MODEL_PATH)
print("File exists:", os.path.exists(BLANKET_MODEL_PATH))

bundled_blanket_path = os.path.join(MODELS_DIR, "blanket_mitigation_best.pt")
shutil.copy2(BLANKET_MODEL_PATH, bundled_blanket_path)
print("Copied best.pt to:", bundled_blanket_path)
# Out:
# Using: /kaggle/input/datasets/sumiyahaider/best-pt/best (2).pt
# File exists: True
# Copied best.pt to: /kaggle/working/phase5_blanket_seed123/models/blanket_mitigation_best.pt

# %% [markdown]
# ## Cell 10 — AFTER (Blanket) evaluation on the same Clean + degraded sets

# %%
blanket_yolo = YOLO(bundled_blanket_path)
blanket_df = evaluate_all_conditions(blanket_yolo, "Blanket")
blanket_csv = os.path.join(RESULTS_DIR, "blanket_results.csv")
blanket_df.to_csv(blanket_csv, index=False)
print("Saved:", blanket_csv)
blanket_df
# Out:
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO11s summary (fused): 101 layers, 9,413,574 parameters, 0 gradients, 21.4 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 32.6±11.9 MB/s, size: 35.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 742.5it/s 2.3s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.1it/s 21.3s0.2s
#                    all       1715       2790      0.875      0.743      0.818      0.618
# Speed: 0.7ms preprocess, 9.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 166.1±15.1 MB/s, size: 183.0 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_1/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 746.5it/s 2.3s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_1 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.7s0.2s
#                    all       1715       2790      0.879      0.741      0.817      0.617
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 215.8±28.9 MB/s, size: 252.9 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_2/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 767.9it/s 2.2s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_2 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.6s0.2s
#                    all       1715       2790      0.879      0.736      0.818      0.616
# Speed: 0.7ms preprocess, 9.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 296.6±26.9 MB/s, size: 312.3 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_3/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 708.7it/s 2.4s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_3 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.1it/s 21.2s0.2s
#                    all       1715       2790      0.865      0.742      0.815      0.611
# Speed: 0.7ms preprocess, 9.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 297.1±47.3 MB/s, size: 315.8 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 723.7it/s 2.4s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.6s0.2s
#                    all       1715       2790      0.871      0.728      0.807      0.604
# Speed: 0.7ms preprocess, 9.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 80.1±18.1 MB/s, size: 83.5 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_1/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 775.5it/s 2.2s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_1 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.6s0.2s
#                    all       1715       2790      0.883      0.738      0.817      0.617
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 62.0±10.2 MB/s, size: 66.3 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_2/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 781.0it/s 2.2s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_2 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.1it/s 21.2s0.2s
#                    all       1715       2790      0.879      0.739      0.815      0.614
# Speed: 0.7ms preprocess, 9.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 49.1±11.0 MB/s, size: 62.8 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_3/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 682.7it/s 2.5s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_3 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.7s0.2s
#                    all       1715       2790       0.87       0.74      0.814      0.612
# Speed: 0.7ms preprocess, 9.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.7±1.6 ms, read: 61.2±14.5 MB/s, size: 69.0 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 736.2it/s 2.3s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/motion_blur/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.6s0.2s
#                    all       1715       2790      0.865       0.74      0.811      0.605
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 63.1±32.8 MB/s, size: 68.7 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_1/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 768.8it/s 2.2s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_1 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.8s0.2s
#                    all       1715       2790      0.879      0.738      0.816      0.618
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 42.8±13.6 MB/s, size: 56.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_2/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 782.2it/s 2.2s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_2 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.6s0.2s
#                    all       1715       2790      0.875      0.745      0.815      0.617
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 51.1±14.4 MB/s, size: 57.7 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_3/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 714.8it/s 2.4s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_3 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.6s0.2s
#                    all       1715       2790      0.873      0.745      0.816      0.617
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 32.7±25.4 MB/s, size: 37.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 756.3it/s 2.3s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 5.2it/s 20.7s0.2s
#                    all       1715       2790      0.882      0.743      0.814      0.611
# Speed: 0.7ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Saved: /kaggle/working/phase5_blanket_seed123/results/blanket_results.csv
#       Model     Degradation  Severity  Precision    Recall     mAP50  \
# 0   Blanket           Clean         0   0.874594  0.743473  0.817841
# 1   Blanket  Gaussian Noise         1   0.878887  0.740744  0.816921
# 2   Blanket  Gaussian Noise         2   0.878660  0.736036  0.817520
# 3   Blanket  Gaussian Noise         3   0.865285  0.741604  0.814890
# 4   Blanket  Gaussian Noise         4   0.870891  0.728169  0.807065
# 5   Blanket     Motion Blur         1   0.882705  0.738157  0.817000
# 6   Blanket     Motion Blur         2   0.878749  0.739268  0.814579
# 7   Blanket     Motion Blur         3   0.870226  0.740314  0.813617
# 8   Blanket     Motion Blur         4   0.865013  0.739583  0.810796
# 9   Blanket       Low Light         1   0.878864  0.738225  0.815660
# 10  Blanket       Low Light         2   0.874904  0.744684  0.815328
# 11  Blanket       Low Light         3   0.873441  0.744833  0.815568
# 12  Blanket       Low Light         4   0.881602  0.743379  0.814080
#
#     mAP50_95  Fire_AP50  Smoke_AP50
# 0   0.617607   0.870284    0.765398
# 1   0.617103   0.870972    0.762870
# 2   0.615873   0.870047    0.764993
# 3   0.610863   0.870318    0.759462
# 4   0.603682   0.865817    0.748313
# 5   0.616672   0.869378    0.764621
# 6   0.614084   0.867697    0.761461
# 7   0.612323   0.865382    0.761853
# 8   0.605439   0.863265    0.758327
# 9   0.618007   0.868192    0.763129
# 10  0.616934   0.868391    0.762265
# 11  0.616595   0.868931    0.762205
# 12  0.610775   0.868021    0.760138

# %% [markdown]
# ## Cell 10b — Confusion matrices (Before vs Blanket, normalized)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

def compute_confusion_matrix_df(model, images_dir, name, conf=EVAL_CONF, iou=IOU_THRESHOLD, imgsz=IMG_SIZE):
    yaml_path = os.path.join(LOGS_DIR, f"data_{name}.yaml")
    make_data_yaml(images_dir, yaml_path, CLASS_NAMES)
    temp_plot_dir = os.path.join(LOGS_DIR, f"cm_temp_{name}")
    metrics = model.val(
        data=yaml_path, imgsz=imgsz, conf=conf, iou=iou, split="val",
        device=DEVICE, verbose=False, plots=True, save_json=False,
        project=temp_plot_dir, name="run", exist_ok=True,
    )
    cm = metrics.confusion_matrix.matrix
    n = cm.shape[0]
    labels = CLASS_NAMES + ["background"] if n == len(CLASS_NAMES) + 1 else [f"class_{i}" for i in range(n)]
    cm_df = pd.DataFrame(cm, index=labels, columns=labels)
    cm_df.index.name = "Predicted"
    cm_df.columns.name = "True"
    return cm_df

def plot_normalized_confusion_matrix(cm_df, title, save_name):
    cm = cm_df.values.astype(float)
    col_sums = cm.sum(axis=0, keepdims=True)
    norm = np.divide(cm, col_sums, out=np.zeros_like(cm), where=col_sums != 0)
    fig, ax = plt.subplots(figsize=(6.5, 6))
    im = ax.imshow(norm, cmap="Blues", vmin=0, vmax=1)
    labels = list(cm_df.index)
    ax.set_xticks(range(len(labels))); ax.set_yticks(range(len(labels)))
    ax.set_xticklabels(labels, rotation=45, ha="right", fontsize=11)
    ax.set_yticklabels(labels, fontsize=11)
    ax.set_xlabel("True Class", fontsize=12); ax.set_ylabel("Predicted Class", fontsize=12)
    ax.set_title(title, fontsize=13)
    for i in range(len(labels)):
        for j in range(len(labels)):
            val = norm[i, j]
            color = "white" if val > 0.5 else "black"
            ax.text(j, i, f"{val:.2f}", ha="center", va="center", color=color, fontsize=11)
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    plt.tight_layout()
    for ext in ("png", "pdf"):
        plt.savefig(os.path.join(PLOTS_DIR, f"{save_name}.{ext}"), dpi=DPI, bbox_inches="tight")
    plt.show()
    plt.close()
    print(f"Saved: {os.path.join(PLOTS_DIR, save_name)}.png / .pdf")

condition_short = {
    "Clean test set": "Clean",
    "Low-Light severity 4": "Low-Light (Sev. 4)",
    "Gaussian Noise severity 4": "Noise (Sev. 4)",
}
conditions_for_cm = [
    ("Clean test set", CLEAN_TEST_IMAGES_DIR, "clean"),
    ("Low-Light severity 4", os.path.join(DEGRADATION_DIRS["Low Light"], "severity_4", "images"), "lowlight_sev4"),
    ("Gaussian Noise severity 4", os.path.join(DEGRADATION_DIRS["Gaussian Noise"], "severity_4", "images"), "noise_sev4"),
]

for label, img_dir, tag in conditions_for_cm:
    if not os.path.isdir(img_dir):
        print(f"Skipping {label}: directory not found.")
        continue
    print(f"\n{label}...")
    cm_before = compute_confusion_matrix_df(before_model, img_dir, f"cm_before_{tag}")
    cm_blanket = compute_confusion_matrix_df(blanket_yolo, img_dir, f"cm_blanket_{tag}")
    cm_before.to_csv(os.path.join(RESULTS_DIR, f"confusion_matrix_before_{tag}.csv"))
    cm_blanket.to_csv(os.path.join(RESULTS_DIR, f"confusion_matrix_blanket_{tag}.csv"))
    short = condition_short.get(label, label)
    plot_normalized_confusion_matrix(cm_before, f"Confusion Matrix ({BEFORE_LABEL}: {short})", f"confusion_matrix_before_{tag}_normalized")
    plot_normalized_confusion_matrix(cm_blanket, f"Confusion Matrix ({BLANKET_LABEL}: {short})", f"confusion_matrix_blanket_{tag}_normalized")
# Out:
# Clean test set...
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 28.0±10.1 MB/s, size: 34.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 690.1it/s 2.5s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 4.6it/s 23.4s0.2s
#                    all       1715       2790      0.869      0.763      0.828      0.625
# Speed: 0.8ms preprocess, 10.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /kaggle/working/phase5_blanket_seed123/logs/cm_temp_cm_before_clean/run
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 42.1±13.6 MB/s, size: 42.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 741.1it/s 2.3s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 4.8it/s 22.3s0.2s
#                    all       1715       2790      0.875      0.743      0.818      0.618
# Speed: 0.8ms preprocess, 9.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /kaggle/working/phase5_blanket_seed123/logs/cm_temp_cm_blanket_clean/run
# Saved: /kaggle/working/phase5_blanket_seed123/plots/confusion_matrix_before_clean_normalized.png / .pdf
# Saved: /kaggle/working/phase5_blanket_seed123/plots/confusion_matrix_blanket_clean_normalized.png / .pdf
#
# Low-Light severity 4...
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 38.9±17.7 MB/s, size: 41.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 661.7it/s 2.6s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 4.9it/s 22.0s0.2s
#                    all       1715       2790      0.878      0.726      0.791      0.599
# Speed: 0.8ms preprocess, 9.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /kaggle/working/phase5_blanket_seed123/logs/cm_temp_cm_before_lowlight_sev4/run
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 47.7±20.5 MB/s, size: 57.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 730.3it/s 2.3s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/low_light/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 4.6it/s 23.4s0.2s
#                    all       1715       2790      0.882      0.743      0.814      0.611
# Speed: 0.8ms preprocess, 10.0ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/phase5_blanket_seed123/logs/cm_temp_cm_blanket_lowlight_sev4/run
# Saved: /kaggle/working/phase5_blanket_seed123/plots/confusion_matrix_before_lowlight_sev4_normalized.png / .pdf
# Saved: /kaggle/working/phase5_blanket_seed123/plots/confusion_matrix_blanket_lowlight_sev4_normalized.png / .pdf
#
# Gaussian Noise severity 4...
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 277.1±57.1 MB/s, size: 359.0 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 765.9it/s 2.2s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 4.8it/s 22.5s0.2s
#                    all       1715       2790      0.664      0.356      0.371      0.276
# Speed: 0.8ms preprocess, 9.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/phase5_blanket_seed123/logs/cm_temp_cm_before_noise_sev4/run
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 216.5±113.1 MB/s, size: 313.9 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_4/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 698.3it/s 2.5s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/degraded_datasets/gaussian_noise/severity_4 is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 4.6it/s 23.4s0.2s
#                    all       1715       2790      0.871      0.728      0.807      0.604
# Speed: 0.8ms preprocess, 9.9ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/phase5_blanket_seed123/logs/cm_temp_cm_blanket_noise_sev4/run
# Saved: /kaggle/working/phase5_blanket_seed123/plots/confusion_matrix_before_noise_sev4_normalized.png / .pdf
# Saved: /kaggle/working/phase5_blanket_seed123/plots/confusion_matrix_blanket_noise_sev4_normalized.png / .pdf

# %% [markdown]
# ## Cell 10c — Precision-Recall curves (Before vs Blanket)

# %%
def plot_pr_curve(model, images_dir, name, display_label, conf=0.001, iou=IOU_THRESHOLD, imgsz=IMG_SIZE):
    yaml_path = os.path.join(LOGS_DIR, f"data_{name}.yaml")
    make_data_yaml(images_dir, yaml_path, CLASS_NAMES)
    save_dir = os.path.join(PLOTS_DIR, f"pr_curve_{name}")
    os.makedirs(save_dir, exist_ok=True)
    model.val(
        data=yaml_path, imgsz=imgsz, conf=conf, iou=iou, split="val",
        device=DEVICE, verbose=False, plots=True, save_json=False,
        project=save_dir, name="run", exist_ok=True,
    )
    run_dir = os.path.join(save_dir, "run")
    candidates = ["BoxPR_curve.png", "PR_curve.png"]
    found = None
    for c in candidates:
        p = os.path.join(run_dir, c)
        if os.path.exists(p):
            found = p
            break
    if found is None:
        print(f"WARNING: no PR curve file found in {run_dir}")
        return

    img = plt.imread(found)
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.imshow(img)
    ax.axis("off")
    ax.set_title(f"Precision vs Recall ({display_label})", fontsize=13, pad=10)
    plt.tight_layout()
    final_path_png = os.path.join(PLOTS_DIR, f"pr_curve_{name}.png")
    final_path_pdf = os.path.join(PLOTS_DIR, f"pr_curve_{name}.pdf")
    plt.savefig(final_path_png, dpi=DPI, bbox_inches="tight")
    plt.savefig(final_path_pdf, dpi=DPI, bbox_inches="tight")
    plt.show()
    plt.close()
    print(f"Saved: {final_path_png} / .pdf")

plot_pr_curve(before_model, CLEAN_TEST_IMAGES_DIR, "pr_before_clean", BEFORE_LABEL)
plot_pr_curve(blanket_yolo, CLEAN_TEST_IMAGES_DIR, "pr_blanket_clean", BLANKET_LABEL)
# Out:
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 22.7±11.0 MB/s, size: 44.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 771.3it/s 2.2s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 4.7it/s 22.7s0.2s
#                    all       1715       2790      0.869      0.763      0.828      0.625
# Speed: 0.9ms preprocess, 9.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/phase5_blanket_seed123/plots/pr_curve_pr_before_clean/run
# Saved: /kaggle/working/phase5_blanket_seed123/plots/pr_curve_pr_before_clean.png / .pdf
# Ultralytics 8.4.137 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 51.2±15.5 MB/s, size: 50.9 KB)
# val: Scanning /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set/labels... 1715 images, 287 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1715/1715 660.9it/s 2.6s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/sumiyahaider/dataset-output-phase-3/clean_test_set is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 108/108 4.7it/s 23.1s0.2s
#                    all       1715       2790      0.875      0.743      0.818      0.618
# Speed: 0.9ms preprocess, 9.8ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/phase5_blanket_seed123/plots/pr_curve_pr_blanket_clean/run
# Saved: /kaggle/working/phase5_blanket_seed123/plots/pr_curve_pr_blanket_clean.png / .pdf

# %% [markdown]
# ## Cell 10e — Per-class AP50 (Fire vs Smoke, Before vs Blanket)

# %%
def plot_per_class_ap_bar(df_before, df_blanket, degradation, severity, save_name):
    row_before = df_before[(df_before["Degradation"] == degradation) & (df_before["Severity"] == severity)]
    row_blanket = df_blanket[(df_blanket["Degradation"] == degradation) & (df_blanket["Severity"] == severity)]
    if row_before.empty or row_blanket.empty:
        print(f"Skipping {save_name}: no data for {degradation} severity {severity}")
        return
    row_before = row_before.iloc[0]
    row_blanket = row_blanket.iloc[0]

    ap_cols = [f"{c}_AP50" for c in CLASS_NAMES]
    before_vals = [row_before.get(c) for c in ap_cols]
    blanket_vals = [row_blanket.get(c) for c in ap_cols]

    x = np.arange(len(CLASS_NAMES))
    width = 0.35
    fig, ax = plt.subplots(figsize=(7, 5))
    bars1 = ax.bar(x - width/2, before_vals, width, label=BEFORE_LABEL, color="#4C72B0")
    bars2 = ax.bar(x + width/2, blanket_vals, width, label=BLANKET_LABEL, color="#DD8452")
    for bars in (bars1, bars2):
        for b in bars:
            h = b.get_height()
            if h is not None:
                ax.annotate(f"{h:.3f}", xy=(b.get_x() + b.get_width() / 2, h),
                            xytext=(0, 3), textcoords="offset points", ha="center", fontsize=9)
    ax.set_xticks(x)
    ax.set_xticklabels(CLASS_NAMES, fontsize=11)
    ax.set_xlabel("Class", fontsize=12)
    ax.set_ylabel("AP@0.5", fontsize=12)
    ax.set_ylim(0, 1.0)
    short_cond = "Clean" if degradation == "Clean" else f"{degradation.split()[0]} (Sev. {severity})"
    ax.set_title(f"AP@0.5 vs Class ({short_cond})", fontsize=13)
    ax.legend()
    ax.grid(axis="y", alpha=0.3)
    plt.tight_layout()
    for ext in ("png", "pdf"):
        plt.savefig(os.path.join(PLOTS_DIR, f"{save_name}.{ext}"), dpi=DPI, bbox_inches="tight")
    plt.show()
    plt.close()
    print(f"Saved: {os.path.join(PLOTS_DIR, save_name)}.png / .pdf")

plot_per_class_ap_bar(before_df, blanket_df, "Clean", 0, "per_class_ap50_clean")
plot_per_class_ap_bar(before_df, blanket_df, "Low Light", 4, "per_class_ap50_lowlight_sev4")
plot_per_class_ap_bar(before_df, blanket_df, "Gaussian Noise", 4, "per_class_ap50_noise_sev4")
plot_per_class_ap_bar(before_df, blanket_df, "Motion Blur", 4, "per_class_ap50_motionblur_sev4")
# Out:
# Saved: /kaggle/working/phase5_blanket_seed123/plots/per_class_ap50_clean.png / .pdf
# Saved: /kaggle/working/phase5_blanket_seed123/plots/per_class_ap50_lowlight_sev4.png / .pdf
# Saved: /kaggle/working/phase5_blanket_seed123/plots/per_class_ap50_noise_sev4.png / .pdf
# Saved: /kaggle/working/phase5_blanket_seed123/plots/per_class_ap50_motionblur_sev4.png / .pdf

# %% [markdown]
# ## Cell 11 — Comparison table: Before vs Blanket (values only, matches Table 2's format)

# %%
merged = before_df.merge(blanket_df, on=["Degradation", "Severity"], suffixes=("_Before", "_Blanket"))

for metric in ["Precision", "Recall", "mAP50", "mAP50_95"]:
    merged[f"{metric}_Improvement_Pct"] = (
        (merged[f"{metric}_Blanket"] - merged[f"{metric}_Before"]) / merged[f"{metric}_Before"].replace(0, np.nan)
    ) * 100.0

comparison_csv = os.path.join(RESULTS_DIR, "before_vs_blanket_comparison.csv")
merged.to_csv(comparison_csv, index=False)
print("Saved:", comparison_csv)

cols = ["Degradation", "Severity",
        "Precision_Before", "Precision_Blanket",
        "Recall_Before", "Recall_Blanket",
        "mAP50_Before", "mAP50_Blanket",
        "mAP50_95_Before", "mAP50_95_Blanket",
        "mAP50_Improvement_Pct"]
print(merged[cols].to_string(index=False))
# Out:
# Saved: /kaggle/working/phase5_blanket_seed123/results/before_vs_blanket_comparison.csv
#    Degradation  Severity  Precision_Before  Precision_Blanket  Recall_Before  Recall_Blanket  mAP50_Before  mAP50_Blanket  mAP50_95_Before  mAP50_95_Blanket  mAP50_Improvement_Pct
#          Clean         0          0.869361           0.874594       0.762934        0.743473      0.828040       0.817841         0.625484          0.617607              -1.231694
# Gaussian Noise         1          0.855555           0.878887       0.716088        0.740744      0.783998       0.816921         0.590691          0.617103               4.199317
# Gaussian Noise         2          0.775929           0.878660       0.576955        0.736036      0.636428       0.817520         0.484954          0.615873              28.454343
# Gaussian Noise         3          0.783000           0.865285       0.465214        0.741604      0.516404       0.814890         0.402309          0.610863              57.800763
# Gaussian Noise         4          0.664069           0.870891       0.356103        0.728169      0.370867       0.807065         0.276117          0.603682             117.616042
#    Motion Blur         1          0.877249           0.882705       0.756887        0.738157      0.827109       0.817000         0.624187          0.616672              -1.222269
#    Motion Blur         2          0.871974           0.878749       0.731861        0.739268      0.809976       0.814579         0.603373          0.614084               0.568323
#    Motion Blur         3          0.870828           0.870226       0.690419        0.740314      0.775272       0.813617         0.566320          0.612323               4.946081
#    Motion Blur         4          0.817626           0.865013       0.657045        0.739583      0.724563       0.810796         0.514225          0.605439              11.901449
#      Low Light         1          0.875656           0.878864       0.758979        0.738225      0.826797       0.815660         0.627010          0.618007              -1.346943
#      Low Light         2          0.874133           0.874904       0.762090        0.744684      0.827069       0.815328         0.627198          0.616934              -1.419570
#      Low Light         3          0.876896           0.873441       0.751325        0.744833      0.820986       0.815568         0.624414          0.616595              -0.659884
#      Low Light         4          0.877971           0.881602       0.725938        0.743379      0.791391       0.814080         0.599147          0.610775               2.866983

# %% [markdown]
# ## Cell 10d — Per-condition metric comparison (Before vs Blanket)

# %%
def plot_metric_comparison(metric, filename_prefix):
    metric_display = {"mAP50": "mAP@0.5", "mAP50_95": "mAP@0.5:0.95",
                       "Precision": "Precision", "Recall": "Recall"}.get(metric, metric)
    for deg in merged["Degradation"].unique():
        if deg == "Clean":
            continue
        sub = merged[merged["Degradation"] == deg].sort_values("Severity")
        plt.figure(figsize=(6.5, 4.5))
        plt.plot(sub["Severity"], sub[f"{metric}_Before"], marker="o", linewidth=2, label=BEFORE_LABEL)
        plt.plot(sub["Severity"], sub[f"{metric}_Blanket"], marker="s", linewidth=2, label=BLANKET_LABEL)
        plt.title(f"{metric_display} vs Severity ({deg})", fontsize=13)
        plt.xlabel("Severity Level")
        plt.ylabel(metric_display)
        plt.xticks(sub["Severity"])
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        safe_deg = deg.replace(" ", "_")
        for ext in ("png", "pdf"):
            plt.savefig(os.path.join(PLOTS_DIR, f"{filename_prefix}_{safe_deg}.{ext}"), dpi=DPI, bbox_inches="tight")
        plt.show()
        plt.close()

for metric in ["mAP50", "mAP50_95", "Precision", "Recall"]:
    plot_metric_comparison(metric, f"before_blanket_{metric.lower()}")

clean_row = merged[merged["Degradation"] == "Clean"]
if not clean_row.empty:
    metrics_list = ["Precision", "Recall", "mAP50", "mAP50_95"]
    before_vals = [clean_row[f"{m}_Before"].values[0] for m in metrics_list]
    blanket_vals = [clean_row[f"{m}_Blanket"].values[0] for m in metrics_list]
    x = np.arange(len(metrics_list))
    width = 0.35
    plt.figure(figsize=(7, 5))
    plt.bar(x - width/2, before_vals, width, label=BEFORE_LABEL)
    plt.bar(x + width/2, blanket_vals, width, label=BLANKET_LABEL)
    plt.xticks(x, metrics_list)
    plt.xlabel("Metric")
    plt.ylabel("Score")
    plt.title(f"{BEFORE_LABEL} vs {BLANKET_LABEL} (Clean Test Set)")
    plt.legend()
    plt.grid(axis="y", alpha=0.3)
    plt.tight_layout()
    for ext in ("png", "pdf"):
        plt.savefig(os.path.join(PLOTS_DIR, f"clean_before_blanket.{ext}"), dpi=DPI, bbox_inches="tight")
    plt.show()
    plt.close()

print("Plots saved to:", PLOTS_DIR)
# Out:
# Plots saved to: /kaggle/working/phase5_blanket_seed123/plots

# %% [markdown]
# ## Cell 12 — Save config + ZIP

# %%
config = {
    "run_type": "Blanket augmentation (ablation control, no evidence gate)",
    "seed": SEED,
    "before_model_path": BEFORE_MODEL_PATH,
    "blanket_model_path": bundled_blanket_path,
    "training_hyperparameters": {
        "epochs": TRAIN_EPOCHS, "batch": TRAIN_BATCH, "optimizer": TRAIN_OPTIMIZER,
        "lr0": TRAIN_LR0, "seed": TRAIN_SEED,
    },
    "blanket_augmentation": {
        "lowlight_prob": BLANKET_LOWLIGHT_PROB, "lowlight_range": BLANKET_LOWLIGHT_FACTOR_RANGE,
        "noise_prob": BLANKET_NOISE_PROB, "noise_range": BLANKET_NOISE_STD_RANGE,
        "blur_prob": BLANKET_BLUR_PROB, "blur_kernel_range": BLANKET_BLUR_KERNEL_RANGE,
    },
    "class_names": CLASS_NAMES,
}
config_path = os.path.join(OUTPUT_ROOT, "phase5_blanket_config.json")
with open(config_path, "w") as f:
    json.dump(config, f, indent=2)
print("Saved:", config_path)

zip_path = shutil.make_archive(f"/kaggle/working/phase5_blanket_results_seed{SEED}", "zip", OUTPUT_ROOT)
print("\nFINAL ZIP:")
print(" ", zip_path)
# Out:
# Saved: /kaggle/working/phase5_blanket_seed123/phase5_blanket_config.json
#
# FINAL ZIP:
#   /kaggle/working/phase5_blanket_results_seed123.zip
